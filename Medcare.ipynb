# %%
import numpy as np 
import pandas as pd

# %%
medicines = pd.read_csv('/Users/saryugundimeda/Downloads/medicinee.csv')

# %%
medicines.head()
# Out:
#    index                                          Drug_Name Reason  \
# 0      1               A CN Gel(Topical) 20gmA CN Soap 75gm   Acne
# 1      2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...   Acne
# 2      3                             ACGEL CL NANO Gel 15gm   Acne
# 3      4                                ACGEL NANO Gel 15gm   Acne
# 4      5                              Acleen 1% Lotion 25ml   Acne
#
#                                          Description
# 0                      Mild to moderate acne (spots)
# 1  A RET 0.025% is a prescription medicine that i...
# 2  It is used to treat acne vulgaris in people 12...
# 3  It is used to treat acne vulgaris in people 12...
# 4  treat the most severe form of acne (nodular ac...

# %%
medicines.shape
# Out:
# (9720, 4)

# %%
medicines.isnull().sum()
# Out:
# index          0
# Drug_Name      0
# Reason         0
# Description    0
# dtype: int64

# %%
medicines.dropna(inplace=True)

# %%
medicines.duplicated().sum()
# Out:
# 0

# %%
medicines['Description']
# Out:
# 0                           Mild to moderate acne (spots)
# 1       A RET 0.025% is a prescription medicine that i...
# 2       It is used to treat acne vulgaris in people 12...
# 3       It is used to treat acne vulgaris in people 12...
# 4       treat the most severe form of acne (nodular ac...
#                               ...
# 9715                              used for treating warts
# 9716                        used to soften the skin cells
# 9717                                       used for scars
# 9718                                      used for wounds
# 9719    used to treat and remove raised warts (usually...
# Name: Description, Length: 9720, dtype: object

# %%
medicines['Description'].apply(lambda x:x.split())
# Out:
# 0                     [Mild, to, moderate, acne, (spots)]
# 1       [A, RET, 0.025%, is, a, prescription, medicine...
# 2       [It, is, used, to, treat, acne, vulgaris, in, ...
# 3       [It, is, used, to, treat, acne, vulgaris, in, ...
# 4       [treat, the, most, severe, form, of, acne, (no...
#                               ...
# 9715                         [used, for, treating, warts]
# 9716                 [used, to, soften, the, skin, cells]
# 9717                                   [used, for, scars]
# 9718                                  [used, for, wounds]
# 9719    [used, to, treat, and, remove, raised, warts, ...
# Name: Description, Length: 9720, dtype: object

# %%
medicines['Reason'] = medicines['Reason'].apply(lambda x:x.split())
medicines['Description'] = medicines['Description'].apply(lambda x:x.split())

# %%
medicines['Description'] = medicines['Description'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['Description'] = medicines['Description'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['tags'] = medicines['Description'] + medicines['Reason']

# %%
new_df = medicines[['index','Drug_Name','tags']]

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# ...     ...                                                ...
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0             [Mild, to, moderate, acne, (spots), Acne]
# 1     [A, RET, 0.025%, is, a, prescription, medicine...
# 2     [It, is, used, to, treat, acne, vulgaris, in, ...
# 3     [It, is, used, to, treat, acne, vulgaris, in, ...
# 4     [treat, the, most, severe, form, of, acne, (no...
# ...                                                 ...
# 9715                [used, for, treating, warts, Wound]
# 9716        [used, to, soften, the, skin, cells, Wound]
# 9717                          [used, for, scars, Wound]
# 9718                         [used, for, wounds, Wound]
# 9719  [used, to, treat, and, remove, raised, warts, ...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# 0                      Mild to moderate acne (spots) Acne
# 1       A RET 0.025% is a prescription medicine that i...
# 2       It is used to treat acne vulgaris in people 12...
# 3       It is used to treat acne vulgaris in people 12...
# 4       treat the most severe form of acne (nodular ac...
#                               ...
# 9715                        used for treating warts Wound
# 9716                  used to soften the skin cells Wound
# 9717                                 used for scars Wound
# 9718                                used for wounds Wound
# 9719    used to treat and remove raised warts (usually...
# Name: tags, Length: 9720, dtype: object

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# ...     ...                                                ...
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0             [Mild, to, moderate, acne, (spots), Acne]
# 1     [A, RET, 0.025%, is, a, prescription, medicine...
# 2     [It, is, used, to, treat, acne, vulgaris, in, ...
# 3     [It, is, used, to, treat, acne, vulgaris, in, ...
# 4     [treat, the, most, severe, form, of, acne, (no...
# ...                                                 ...
# 9715                [used, for, treating, warts, Wound]
# 9716        [used, to, soften, the, skin, cells, Wound]
# 9717                          [used, for, scars, Wound]
# 9718                         [used, for, wounds, Wound]
# 9719  [used, to, treat, and, remove, raised, warts, ...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# /var/folders/vm/tyckj96j06b8sk8ypzb_3f000000gn/T/ipykernel_9618/3089450492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# ...     ...                                                ...
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0                    Mild to moderate acne (spots) Acne
# 1     A RET 0.025% is a prescription medicine that i...
# 2     It is used to treat acne vulgaris in people 12...
# 3     It is used to treat acne vulgaris in people 12...
# 4     treat the most severe form of acne (nodular ac...
# ...                                                 ...
# 9715                      used for treating warts Wound
# 9716                used to soften the skin cells Wound
# 9717                               used for scars Wound
# 9718                              used for wounds Wound
# 9719  used to treat and remove raised warts (usually...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# /var/folders/vm/tyckj96j06b8sk8ypzb_3f000000gn/T/ipykernel_9618/3214958533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# ...     ...                                                ...
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0                    mild to moderate acne (spots) acne
# 1     a ret 0.025% is a prescription medicine that i...
# 2     it is used to treat acne vulgaris in people 12...
# 3     it is used to treat acne vulgaris in people 12...
# 4     treat the most severe form of acne (nodular ac...
# ...                                                 ...
# 9715                      used for treating warts wound
# 9716                used to soften the skin cells wound
# 9717                               used for scars wound
# 9718                              used for wounds wound
# 9719  used to treat and remove raised warts (usually...
#
# [9720 rows x 3 columns]

# %%
import nltk
# Out:
# /Users/saryugundimeda/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words='english',max_features=5000)

# %%
def stem(text):
    y = []

    for i in text.split():
        y.append(ps.stem(i))

    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# /var/folders/vm/tyckj96j06b8sk8ypzb_3f000000gn/T/ipykernel_9618/3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
cv.fit_transform(new_df['tags']).toarray().shape
# Out:
# (9720, 788)

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
cv.get_feature_names()
# Out:
# /Users/saryugundimeda/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['025',
#  '12',
#  '16',
#  '18',
#  'abdomin',
#  'abl',
#  'ach',
#  'acid',
#  'acn',
#  'acne',
#  'acquir',
#  'action',
#  'activ',
#  'acut',
#  'acute',
#  'adequ',
#  'adhd',
#  'adjunct',
#  'adolesc',
#  'adult',
#  'adults',
#  'affect',
#  'ag',
#  'age',
#  'aids',
#  'allerg',
#  'allergen',
#  'allergi',
#  'allow',
#  'alon',
#  'alzheim',
#  'alzheimer',
#  'amoebiasi',
#  'anaemia',
#  'anal',
#  'angina',
#  'angl',
#  'ani',
#  'ankylos',
#  'anorexia',
#  'anoth',
#  'anti',
#  'antioxid',
#  'antipsychot',
#  'antiretrovir',
#  'anxieti',
#  'anxiou',
#  'anxious',
#  'apnoea',
#  'appear',
#  'appetit',
#  'appetite',
#  'appli',
#  'appropri',
#  'area',
#  'arrhythmia',
#  'arrhythmiasi',
#  'arteri',
#  'arthralgia',
#  'arthriti',
#  'associ',
#  'atherothrombot',
#  'athlete',
#  'atop',
#  'atrial',
#  'attack',
#  'awak',
#  'b1',
#  'b2',
#  'b3',
#  'b5',
#  'b6',
#  'babi',
#  'backache',
#  'bacteri',
#  'bacteria',
#  'balanc',
#  'balanitis',
#  'bandag',
#  'becom',
#  'behaviour',
#  'beliefs',
#  'benefit',
#  'beta',
#  'biliari',
#  'biotin',
#  'bite',
#  'blackhead',
#  'blackheads',
#  'bleaches',
#  'bleed',
#  'bloating',
#  'block',
#  'blood',
#  'bodi',
#  'body',
#  'bon',
#  'bone',
#  'bones',
#  'bowel',
#  'brain',
#  'breakdown',
#  'breath',
#  'brighten',
#  'bronchiti',
#  'brown',
#  'bursitis',
#  'calcium',
#  'calm',
#  'cancer',
#  'candid',
#  'candidiasis',
#  'carbohydr',
#  'cardiovascular',
#  'care',
#  'carrier',
#  'cartilag',
#  'case',
#  'cases',
#  'cataract',
#  'caus',
#  'cavity',
#  'cell',
#  'certain',
#  'chanc',
#  'chang',
#  'characteris',
#  'chemic',
#  'chemotherapi',
#  'chest',
#  'chickenpox',
#  'childhood',
#  'children',
#  'chlosma',
#  'cholesterol',
#  'chronic',
#  'clean',
#  'cleaner',
#  'cleanser',
#  'clear',
#  'clot',
#  'cmv',
#  'cold',
#  'colds',
#  'colic',
#  'colon',
#  'colorect',
#  'coma',
#  'combin',
#  'common',
#  'complet',
#  'complexion',
#  'concomit',
#  'condit',
#  'conditions',
#  'confused',
#  'confusion',
#  'congestion',
#  'conjunct',
#  'consciousness',
#  'consid',
#  'consist',
#  'constip',
#  'constipation',
#  'continu',
#  'contracept',
#  'control',
#  'contusion',
#  'convent',
#  'convulsion',
#  'corpori',
#  'corticosteroid',
#  'cough',
#  'cramp',
#  'cream',
#  'cruri',
#  'cushion',
#  'cycl',
#  'cytomegaloviru',
#  'cytoprotect',
#  'd3',
#  'daili',
#  'damag',
#  'dandruff',
#  'dark',
#  'death',
#  'decreas',
#  'defici',
#  'degrad',
#  'degre',
#  'delay',
#  'demand',
#  'dementia',
#  'dental',
#  'deposit',
#  'depress',
#  'depressed',
#  'dermat',
#  'deterg',
#  'diabet',
#  'diagnost',
#  'diarrhea',
#  'diarrhoea',
#  'diet',
#  'differ',
#  'difficult',
#  'difficulti',
#  'digest',
#  'digestion',
#  'dilate',
#  'discolor',
#  'discoloured',
#  'diseas',
#  'disord',
#  'disorder',
#  'disorders',
#  'displac',
#  'distens',
#  'dizzi',
#  'doctor',
#  'doe',
#  'drain',
#  'drained',
#  'dri',
#  'drop',
#  'drowsi',
#  'drugs',
#  'dull',
#  'dure',
#  'dysmenorrhea',
#  'ear',
#  'ears',
#  'eczema',
#  'effect',
#  'effects',
#  'elbow',
#  'element',
#  'emot',
#  'encephalopathi',
#  'endometriosi',
#  'energi',
#  'energy',
#  'enhanc',
#  'enlarg',
#  'enzym',
#  'enzyme',
#  'epicondylitis',
#  'episod',
#  'especi',
#  'essenti',
#  'event',
#  'excess',
#  'exercis',
#  'exfoli',
#  'exocrin',
#  'extern',
#  'extra',
#  'eye',
#  'eyes',
#  'face',
#  'fade',
#  'fail',
#  'failur',
#  'failure',
#  'fast',
#  'fat',
#  'fatigue',
#  'fats',
#  'fatti',
#  'febril',
#  'feed',
#  'feel',
#  'feet',
#  'fever',
#  'feverish',
#  'fibril',
#  'fine',
#  'fissur',
#  'flat',
#  'flatul',
#  'flatulence',
#  'flexibl',
#  'flow',
#  'flu',
#  'fluid',
#  'flutter',
#  'focus',
#  'folic',
#  'follow',
#  'food',
#  'foot',
#  'form',
#  'format',
#  'free',
#  'fresh',
#  'friction',
#  'function',
#  'fungal',
#  'fungi',
#  'fungu',
#  'gain',
#  'gener',
#  'genit',
#  'gland',
#  'glaucoma',
#  'glow',
#  'gonorrhoea',
#  'good',
#  'gout',
#  'gradual',
#  'gravi',
#  'growth',
#  'guilty',
#  'gum',
#  'ha',
#  'haematopoiesi',
#  'haemorrhoid',
#  'haemorrhoidectomi',
#  'haemorrhoids',
#  'hair',
#  'hallucinations',
#  'hands',
#  'hard',
#  'hay',
#  'head',
#  'headach',
#  'headache',
#  'heal',
#  'health',
#  'healthy',
#  'hear',
#  'hearing',
#  'heart',
#  'heartbeat',
#  'help',
#  'hepat',
#  'herp',
#  'high',
#  'hiv',
#  'hives',
#  'hormon',
#  'hospit',
#  'human',
#  'hygien',
#  'hypercalcaemia',
#  'hyperparathyroid',
#  'hyperpigment',
#  'hyperpigmentation',
#  'hypertens',
#  'hypertension',
#  'hyperthyroid',
#  'hypertrophi',
#  'hypnosi',
#  'hypotens',
#  'hypothyroid',
#  'hypothyroidism',
#  'hyroid',
#  'ibs',
#  'immun',
#  'immunodefici',
#  'improv',
#  'includ',
#  'incoher',
#  'incomplet',
#  'increas',
#  'indic',
#  'indigest',
#  'induc',
#  'infect',
#  'infection',
#  'infections',
#  'infest',
#  'inflamm',
#  'inflammatori',
#  'influenza',
#  'infrequ',
#  'inguinalis',
#  'inhal',
#  'inhibitor',
#  'injuri',
#  'inner',
#  'insect',
#  'insid',
#  'insomnia',
#  'insufficiency',
#  'integr',
#  'intens',
#  'interdigit',
#  'intern',
#  'interrupt',
#  'intestin',
#  'intestinal',
#  'intoler',
#  'invas',
#  'involuntari',
#  'iodine',
#  'iritis',
#  'iron',
#  'irrit',
#  'itch',
#  'jewelleri',
#  'jock',
#  'joint',
#  'kidney',
#  'kit',
#  'knees',
#  'known',
#  'lack',
#  'lactat',
#  'lead',
#  'learning',
#  'left',
#  'level',
#  'lice',
#  'life',
#  'ligaments',
#  'line',
#  'lip',
#  'liquid',
#  'liv',
#  'live',
#  'liver',
#  'long',
#  'look',
#  'lose',
#  'loss',
#  'lotion',
#  'lower',
#  'lung',
#  'lvh',
#  'mainli',
#  'maintain',
#  'major',
#  'make',
#  'malari',
#  'malaria',
#  'malignancies',
#  'manag',
#  'manganese',
#  'mani',
#  'manuum',
#  'marrow',
#  'medic',
#  'medicin',
#  'melanin',
#  'melasma',
#  'mellitu',
#  'memori',
#  'men',
#  'mening',
#  'menopaus',
#  'mental',
#  'metabol',
#  'methyl',
#  'micronutri',
#  'migrain',
#  'migraine',
#  'mild',
#  'milk',
#  'miner',
#  'minor',
#  'mistaken',
#  'mobil',
#  'moder',
#  'moderate',
#  'moistur',
#  'molybdenum',
#  'motion',
#  'movement',
#  'movements',
#  'muscl',
#  'muscular',
#  'musculoskelet',
#  'myalgia',
#  'myasthenia',
#  'mydriasi',
#  'myeloid',
#  'narrow',
#  'nasal',
#  'natur',
#  'nausea',
#  'need',
#  'nephropathy',
#  'nerv',
#  'nervosa',
#  'nervousness',
#  'nettl',
#  'neuralgia',
#  'neutral',
#  'newborns',
#  'nodular',
#  'non',
#  'normal',
#  'nose',
#  'nutrient',
#  'nutrit',
#  'occur',
#  'ocular',
#  'oili',
#  'older',
#  'onli',
#  'op',
#  'open',
#  'oper',
#  'oral',
#  'origin',
#  'osteoarthr',
#  'osteodystrophy',
#  'osteoporosi',
#  'oxid',
#  'oxidation',
#  'pah',
#  'pain',
#  'pancrea',
#  'pancreat',
#  'paralys',
#  'parathyroid',
#  'parkinson',
#  'passag',
#  'patch',
#  'patches',
#  'patient',
#  'pectori',
#  'pectoris',
#  'pedis',
#  'pelvic',
#  'penil',
#  'peopl',
#  'peptid',
#  'period',
#  'physic',
#  'piles',
#  'pimpl',
#  'pimple',
#  'pityriasi',
#  'polysaccharid',
#  'portal',
#  'post',
#  'potent',
#  'power',
#  'pre',
#  'prednisolon',
#  'pregnanc',
#  'prematur',
#  'preoper',
#  'prescrib',
#  'prescript',
#  'present',
#  'pressur',
#  'prevent',
#  'prexia',
#  'primari',
#  'prinzmet',
#  'problem',
#  'procedur',
#  'process',
#  'proctiti',
#  'produc',
#  'product',
#  'progress',
#  'prolactin',
#  'promot',
#  'properti',
#  'protect',
#  'provid',
#  'pseudo',
#  'psychosi',
#  'psychosomat',
#  'pulmonari',
#  'pupil',
#  'pyrexia',
#  'rabi',
#  'radicals',
#  'radiculitis',
#  'rais',
#  'rarer',
#  'rash',
#  'react',
#  'reaction',
#  'receiv',
#  'recommend',
#  'red',
#  'reduc',
#  'reduct',
#  'refer',
#  'regener',
#  'regimen',
#  'relat',
#  'releief',
#  'relief',
#  'reliev',
#  'reliv',
#  'remov',
#  'renal',
#  'repair',
#  'replac',
#  'reproduct',
#  'resist',
#  'respiratori',
#  'respond',
#  'respons',
#  'restor',
#  'ret',
#  'retin',
#  'rheumat',
#  'ring',
#  'ringworm',
#  'root',
#  'rosacea',
#  'scabi',
#  'scali',
#  'scalp',
#  'scar',
#  'schizophren',
#  'schizophrenia',
#  'seborrh',
#  'sed',
#  'sedat',
#  'sens',
#  'sever',
#  'shingl',
#  'short',
#  'sick',
#  'sickness',
#  'silki',
#  'simpl',
#  'simplex',
#  'sinusitis',
#  'skelet',
#  'skin',
#  'sleep',
#  'slow',
#  'small',
#  'smoke',
#  'smooth',
#  'soaps',
#  'soar',
#  'soft',
#  'soften',
#  'soothen',
#  'sore',
#  'sores',
#  'spasmod',
#  'speech',
#  'speed',
#  'spondyl',
#  'spot',
#  'spots',
#  'sprain',
#  'spread',
#  'stabil',
#  'starch',
#  'start',
#  'state',
#  'steroids',
#  'stiff',
#  'stomach',
#  'stools',
#  'stop',
#  'strains',
#  'strengthen',
#  'stroke',
#  'structur',
#  'substanc',
#  'suffer',
#  'sugar',
#  'sunburn',
#  'sunscreen',
#  'suppl',
#  'supplement',
#  'support',
#  'surgeri',
#  'surgic',
#  'suspiciousness',
#  'sweat',
#  'swell',
#  'swelling',
#  'swollen',
#  'symptom',
#  'symptomat',
#  'symptoms',
#  'syndrom',
#  'synovi',
#  'synovitis',
#  'synthesi',
#  'synthet',
#  'syphilis',
#  'tablet',
#  'tachycardia',
#  'task',
#  'temperature',
#  'tender',
#  'tendonitis',
#  'tens',
#  'term',
#  'textur',
#  'therapi',
#  'therebi',
#  'thi',
#  'thing',
#  'throat',
#  'thrombolysi',
#  'thrush',
#  'thu',
#  'thyroid',
#  'thyroxin',
#  'time',
#  'tinea',
#  'tinnitus',
#  'tissu',
#  'tissues',
#  'toe',
#  'tone',
#  'tonsil',
#  'tonsilitis',
#  'tonsillectomi',
#  'toothach',
#  'toothache',
#  'topic',
#  'trace',
#  'tract',
#  'transmit',
#  'transplant',
#  'trauma',
#  'traumat',
#  'travel',
#  'treat',
#  'treatment',
#  'tremor',
#  'triglycerid',
#  'tubercular',
#  'type',
#  'ulcer',
#  'unabl',
#  'unbalanc',
#  'uncompl',
#  'uneven',
#  'unstabl',
#  'unusu',
#  'unwant',
#  'upper',
#  'uptak',
#  'urate',
#  'ureter',
#  'uric',
#  'urinari',
#  'use',
#  'uses',
#  'usual',
#  'uveiti',
#  'vaccin',
#  'vagin',
#  'variant',
#  'varieti',
#  'ventricular',
#  'verruca',
#  'versicolor',
#  'vertigo',
#  'vessel',
#  'viral',
#  'viru',
#  'virus',
#  'vitamin',
#  'vitamins',
#  'volume',
#  'vomit',
#  'vulgari',
#  'wall',
#  'wart',
#  'wash',
#  'weak',
#  'weaken',
#  'weight',
#  'wet',
#  'whilst',
#  'white',
#  'widen',
#  'withdrawn',
#  'womb',
#  'women',
#  'work',
#  'worsen',
#  'wound',
#  'wrinkl',
#  'wrinkles',
#  'year',
#  'younger',
#  'zinc']

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.25197632, 0.43643578, ..., 0.        , 0.        ,
#         0.        ],
#        [0.25197632, 1.        , 0.25660012, ..., 0.19245009, 0.1490712 ,
#         0.0860663 ],
#        [0.43643578, 0.25660012, 1.        , ..., 0.11111111, 0.0860663 ,
#         0.0993808 ],
#        ...,
#        [0.        , 0.19245009, 0.11111111, ..., 1.        , 0.77459667,
#         0.2981424 ],
#        [0.        , 0.1490712 , 0.0860663 , ..., 0.77459667, 1.        ,
#         0.34641016],
#        [0.        , 0.0860663 , 0.0993808 , ..., 0.2981424 , 0.34641016,
#         1.        ]])

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[1]
# Out:
# array([0.25197632, 1.        , 0.25660012, ..., 0.19245009, 0.1490712 ,
#        0.0860663 ])

# %%
def recommend(medicine):
    medicine_index = new_df[new_df['Drug_Name'] == medicine].index[0]
    distances = similarity[medicine_index]
    medicines_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    
    for i in medicines_list:
        print(new_df.iloc[i[0]].Drug_Name)

# %%
recommend("Paracetamol 125mg Syrup 60mlParacetamol 500mg Tablet 10'S")
# Out:
# Oxypamol D Tablet 10'S
# Pacimol MF Tablet 10'S
# Painil Plus 100/500mg Tablet 10'S
# Pamagin Plus Gel 30gm
# Paracetamol 125mg Syrup 60mlParacetamol 500mg Tablet 10'S

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('medicine_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
